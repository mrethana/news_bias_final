# %%
import ipywidgets as widgets
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import Image
from IPython.core.display import HTML 
import time
from ipywidgets import FloatProgress
from IPython.display import display
import pafy
from bs4 import BeautifulSoup
import requests
import re

# %%
html_page = requests.get('https://www.youtube.com/results?search_query=russian+hacking+') #Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser', from_encoding='utf-8')
videos = soup.findAll('a')

# %%
len(videos)
# Out:
# 126

# %%
x = videos[45]

# %%
x
# Out:
# <a aria-describedby="description-id-116026" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEUQ3DAYACITCL2WhO2-yt0CFdecwQodXsIMVyj0JFIPcnVzc2lhbiBoYWNraW5n" dir="ltr" href="/watch?v=4uUfYtHfw3A" rel="spf-prefetch" title="Rod Rosenstein Details The Extent Of Russians’ Hacking In 2016 Election | NBC News">Rod Rosenstein Details The Extent Of Russians’ Hacking In 2016 Election | NBC News</a>

# %%
len(x.get('class'))
# Out:
# 6

# %%
x.get('href')
# Out:
# '/watch?v=4uUfYtHfw3A'

# %%
x.get('href')[-11:]
# Out:
# '4uUfYtHfw3A'

# %%
x.get('dir')
# Out:
# 'ltr'

# %%
x='hello'

# %%
def pull_videos(parameter):
    list_dicts = []
    split = parameter.split()
    if len(split) < 2:
        split.append('')
    html_page = requests.get('https://www.youtube.com/results?search_query='+split[0]+'+'+'+'+split[1])
    soup = BeautifulSoup(html_page.content, 'html.parser', from_encoding='utf-8')
    videos = soup.findAll('a')
    videos = videos[40:]
    for video in videos:
        if video.get('href')[:9] == '/watch?v=':
            url = "https://www.youtube.com" + video.get('href')
            video = pafy.new(url)
            data = {'author':video.author, 'content':video.category,'description':video.description,'publishedAt':video.published, 'source_id':video.username, 'source_name':video.author,'title':video.title,'url':url,'urltoImage':video.thumb}
            list_dicts.append(data)
    return list_dicts

# %%
x = pull_videos('Brett Kavanaugh')

# %%
df = pd.DataFrame(x)

# %%
df
# Out:
#                              author          content  \
# 0                             MSNBC  News & Politics
# 1                             MSNBC  News & Politics
# 2                             MSNBC  News & Politics
# 3                             MSNBC  News & Politics
# 4                             MSNBC  News & Politics
# 5                             MSNBC  News & Politics
# 6                             MSNBC  News & Politics
# 7                             MSNBC  News & Politics
# 8                             MSNBC  News & Politics
# 9                             MSNBC  News & Politics
# 10                    Guardian News  News & Politics
# 11                    Guardian News  News & Politics
# 12   Full Frontal with Samantha Bee    Entertainment
# 13   Full Frontal with Samantha Bee    Entertainment
# 14                            MSNBC  News & Politics
# 15                            MSNBC  News & Politics
# 16                            MSNBC  News & Politics
# ...

# %%
# https://www.youtube.com/results?search_query=brett+kavanaugh+

# %%
url = "https://www.youtube.com" + x.get('href')
video = pafy.new(url)

# %%
video.username
# Out:
# 'guardianwires'

# %%
Index(['Unnamed: 0', 'author', 'content', 'description', 'publishedAt',
       'source_id', 'source_name', 'title', 'url', 'urlToImage', 'polarity',
       'length', 'article_similarity', 'source_similarity',
       'cosine_similarity', 'subject_matter', 'cluster'],
      dtype='object')
