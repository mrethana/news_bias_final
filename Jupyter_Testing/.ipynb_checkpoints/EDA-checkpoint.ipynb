# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.tokenize import RegexpTokenizer
from textblob import TextBlob
from nltk.corpus import stopwords 
import re
nltk.download('maxent_ne_chunker')
from nltk.tree import Tree
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
NOUNS = ['NN', 'NNS', 'NNP', 'NNPS']
VERBS = ['VB', 'VBG', 'VBD', 'VBN', 'VBP', 'VBZ']

# %%
# df = df[(~df.source_name.isin(['Bloomberg', 'Financial Times','IGN']))]
# df = df.drop_duplicates(subset='text')
# df = df.reset_index(drop=True)

# %%
df = pd.read_csv('../Archive_CSV/final_corpus_labeled.csv', index_col=0)

# %%
NOUNS = ['NN', 'NNS', 'NNP', 'NNPS']
VERBS = ['VB', 'VBG', 'VBD', 'VBN', 'VBP', 'VBZ']
stopwords= set(stopwords.words('english')) 

def clean_document(document):
    document = re.sub('[^A-Za-z .-]+', ' ', document)
    document = ' '.join(document.split())
    document = ' '.join([i for i in document.split() if i not in stopwords])
    return document

# %%
def get_frequent_nouns(clean_document):
    words = nltk.tokenize.word_tokenize(clean_document)
    words = [word.lower() for word in words if word not in stopwords]
    fdist = nltk.FreqDist(words)
    most_freq_nouns = [word for word, count in fdist.most_common(10)
                   if nltk.pos_tag([word])[0][1] in NOUNS]
    return most_freq_nouns

# %%
def tokenize_sentences(clean_document):
    sentences = nltk.sent_tokenize(clean_document)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    return sentences
def tag_parts_of_sentences(sentences):
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    return sentences
def recognize_entities(tagged_sentences):
    entities = []
    for tagged_sentence in tagged_sentences:
        for chunk in nltk.ne_chunk(tagged_sentence):
            if type(chunk) == nltk.tree.Tree:
                entities.append(' '.join([c[0] for c in chunk]).lower())
    top_10_entities = [word for word, count in nltk.FreqDist(entities).most_common(10)]
    return entities, top_10_entities

# %%
def subject_nouns(top_10_entities, most_freq_nouns):
    subject_nouns = [entity for entity in top_10_entities if entity.split()[0] in most_freq_nouns]
    return subject_nouns

# %%
def pull_all_subjects(corpus_text):
    main_subject = []
    subject_two = []
    counter = 0
    for document in corpus_text:
        clean_doc = clean_document(document)
        most_freq_nouns = get_frequent_nouns(clean_doc)
        sentences = tokenize_sentences(clean_doc)
        tagged_sentences = tag_parts_of_sentences(sentences)
        entities, top_10_entities = recognize_entities(tagged_sentences)
        all_subject_nouns = subject_nouns(top_10_entities,most_freq_nouns)
        if len(all_subject_nouns) > 0:
            main_subject.append(all_subject_nouns[0])
            print(all_subject_nouns[0])
        else:
            main_subject.append('no_subject_found')
        if len(all_subject_nouns) > 1:
            subject_two.append(all_subject_nouns[1])
            print(all_subject_nouns[1])
        else:
            subject_two.append('one_main_subject')
        counter +=1
        print(counter)
    return main_subject, subject_two

# %%
main_subjects, second_subjects = pull_all_subjects(list(df.text))
# Out:
# qualcomm
# apple
# 1
# microsoft
# washington
# 2
# palihapitiya
# hamid maidenberg
# 3
# 4
# rappi
# latin america
# 5
# airbnb
# airbnb ceo brian chesky
# 6
# trump
# times
# 7
# 8
# trump
# nbc
# 9
# rosenstein
# axios
# 10
# rosenstein
# 11
# democrats
# supreme court
# 12
# mcgahn
# axios mcgahn
# 13
# trump
# cohn
# 14
# 15
# trump
# u.s.
# 16
# trump
# fear
# 17
# trump
# 18
# obama
# illinois
# 19
# rudy giuliani
# giuliani
# 20
# 21
# omarosa
# 22
# facebook
# recode
# 23
# bezos
# washington
# 24
# 25
# india
# gay
# 26
# ap
# trump
# 27
# u.s.
# kushner greenblatt israelis
# 28
# russia
# trump
# 29
# pompeo
# russia
# 30
# u.s.
# jerusalem
# 31
# china
# pope francis
# 32
# super
# typhoon jebi
# 33
# alerts
# test national wireless emergency alert system
# 34
# syria
# benjamin netanyahu
# 35
# vimeo
# vimeo stock
# 36
# tech
# 37
# eu
# 38
# democrats
# axios
# 39
# lee
# u.s.
# 40
# amazon
# facebook google twitter apple amazon
# 41
# ftc
# 42
# 43
# hbo emmy
# hbo
# 44
# brazil federal university rio grande twitter
# brazil michel temer
# 45
# antarctica
# ohio state
# 46
# europe
# measles
# 47
# baltimore
# baltimore health commissioner
# 48
# house
# 49
# u.s.
# qualcomm
# 50
# trump
# house
# 51
# 52
# trump
# axios
# 53
# china
# google
# 54
# north korea
# maxwell
# 55
# u.s.
# china
# 56
# china
# google
# 57
# 58
# house
# 59
# bolton bolton
# 60
# cybereason
# tabletop
# 61
# u.s.
# 62
# trump
# 63
# trump
# axios
# 64
# house
# house democrats for people
# 65
# mike allen
# 66
# facebook
# twitter
# 67
# cook
# 68
# trump
# 69
# bob mueller
# bob bauer
# 70
# mexico
# state department
# 71
# 72
# ebola
# butembo
# 73
# unicef
# axios
# 74
# rebecca messina
# beam suntory
# 75
# network
# tech
# 76
# u.s.
# 77
# u.s.
# america
# 78
# itc
# 79
# moonves
# cbs
# 80
# nike
# nikes
# 81
# alibaba
# jack ma
# 82
# 83
# goldman
# goldman sachs
# 84
# comcast
# fox
# 85
# stocks
# bloomberg
# 86
# amazon
# apple
# 87
# 88
# kaepernick
# nike
# 89
# moonves
# cbs
# 90
# bloomberg
# mercedes
# 91
# 92
# u.s.
# juncker
# 93
# commerce
# 94
# benioff
# marc
# 95
# u.s.
# 96
# cbd
# coca-cola
# 97
# 98
# nbc
# nbc news
# 99
# tesla
# musk
# 100
# nike
# shares
# 101
# nike
# apex marketing bloomberg
# 102
# u.s.
# 103
# nike
# colin kaepernick
# 104
# levi
# bergh
# 105
# cbs les moonves
# alibaba jack ma
# 106
# 107
# china
# u.s.
# 108
# 109
# business insider
# 110
# musk
# tesla
# 111
# port authority
# 112
# medicaid
# bobby
# 113
# medicare
# u.s.
# 114
# india
# modi
# 115
# house republicans
# health care
# 116
# 117
# donaldson
# toronto
# 118
# booker
# nba
# 119
# bolt
# 120
# mack
# nfl
# 121
# embiid
# nba
# 122
# bears
# mack
# 123
# fortnite summer
# 124
# breida
# morris
# 125
# celta vigo
# madrid
# 126
# federer
# 127
# murray
# nba
# 128
# gronkowski
# patriots gronkowski
# 129
# ohio state
# alabama
# 130
# simms lefkoe
# 131
# lloyd
# stephanie
# 132
# lahyani
# kyrgios
# 133
# williams
# nadal
# 134
# 135
# ohio state
# herman
# 136
# leganes
# la liga
# 137
# bournemouth
# chelsea
# 138
# nadal
# khachanov
# 139
# johnson
# bryson
# 140
# grade
# 141
# italiangp
# ferrari
# 142
# positional
# 143
# mcnair
# maryland
# 144
# robison
# 145
# nba
# miami heat
# 146
# serena
# williams
# 147
# los
# 148
# perriman
# ravens
# 149
# griffin
# jackson
# 150
# freeman
# 151
# williams
# nadal
# 152
# 153
# storm
# panthers
# 154
# federer
# nishioka
# 155
# lazio
# football italia
# 156
# schumer
# 157
# mercury
# wnba finals
# 158
# djokovic
# keys
# 159
# victory royale
# morgausse
# 160
# neymar
# london
# 161
# judge
# 162
# sousa
# djokovic
# 163
# nfl
# titans
# 164
# saban
# alabama
# 165
# williams
# kanepi
# 166
# larson
# keselowski
# 167
# ancer
# dechambeau
# 168
# kalil
# matt kalil
# 169
# woods
# tiger woods
# 170
# nadal
# u.s.
# 171
# del mar fairgrounds del mar california
# meyer andrew nomura fox san diego
# 172
# murray
# middleton
# 173
# week
# fantasy
# 174
# lions
# detroit lions
# 175
# week
# darnold
# 176
# argentina
# salah
# 177
# leonard
# raptors
# 178
# perry
# usa gymnastics
# 179
# champions league
# league
# 180
# durant
# frazier
# 181
# murray
# verdasco
# 182
# milwaukee bucks
# knicks
# 183
# cfb
# cfb players
# 184

# %%
subject_nouns_test = [entity for entity in top_10_entities if entity.split()[0] in most_freq_nouns]

# %%
from nltk import DefaultTagger, UnigramTagger, BigramTagger, TrigramTagger
nltk.download('conll2000')
nltk.download('treebank')
train_sents = nltk.corpus.brown.tagged_sents()
train_sents += nltk.corpus.conll2000.tagged_sents()
train_sents += nltk.corpus.treebank.tagged_sents()
# Create instance of SubjectTrigramTagger
t0 = DefaultTagger('NN')
t1 = UnigramTagger(train_sents, backoff=t0)
t2 = BigramTagger(train_sents, backoff=t1)
trigram_tagger = TrigramTagger(train_sents, backoff=t2)
# Out:
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
subject = subject_nouns_test[0]

# %%
subject
# Out:
# 'microsoft'

# %%
document
# Out:
# 'In move could prompt companies offer paid parental leave Microsoft announcing today require U.S.-based suppliers vendors employees offer benefits. Why matters Many leading companies offer paid leave others need push. History shows progressive companies require benefits policies suppliers help increase adoption. Microsoft move alone mean many thousands new workers getting paid parental leave company partners U.S. Some states already laws offering mandating paid parental leave including California. Microsoft home state Washington also enacted paid parental leave go effect . As looked legislation however realized benefit employees suppliers Washington state leave thousands valued contributors outside Washington behind Microsoft general counsel Dev Stahlkopf said blog post. So made decision apply Washingtons parental leave requirement broadly wait begin implementation. What saying Activists praised move National Partnership Women Families VP Vicki Shabo calling bold impressive. It showcases ripple effects state-level public policy changes like Washington state paid family medical leave program adopted last year canhave changing private sector practice behavior said. History lesson It first time Microsoft required suppliers offer specific benefits. Three years ago company insisted partners offer full-time workers least days paid time year.'

# %%
def tag_sentences(subject, document):
    """Returns tagged sentences using POS tagging"""
#     trigram_tagger = trained_tagger(existing=True)

    # Tokenize Sentences and words
    sentences = tokenize_sentences(document)
    merge_multi_word_subject(sentences, subject)

    # Filter out sentences where subject is not present
    sentences = [sentence for sentence in sentences if subject in
                [word.lower() for word in sentence]]

    # Tag each sentence
    tagged_sents = [trigram_tagger.tag(sent) for sent in sentences]
    return tagged_sents

# %%
tagged_sents = tag_sentences(subject, document)

# %%
 svos = [get_svo(sentence, subject)for sentence in tagged_sents]

# %%
for svo in svos:
        if svo:
            print(svo)
# Out:
# {'subject': 'microsoft', 'action': 'require', 'object': 'U.S.-based', 'phrase': [('Microsoft', 'NNP'), ('announcing', 'VBG'), ('today', 'NR'), ('require', 'VB'), ('U.S.-based', 'NN')]}
# {'subject': 'microsoft', 'action': 'mean', 'object': 'thousands', 'phrase': [('Microsoft', 'NNP'), ('move', 'NN'), ('alone', 'RB'), ('mean', 'VB'), ('many', 'AP'), ('thousands', 'NNS')]}
# {'subject': 'microsoft', 'action': 'go', 'object': 'effect', 'phrase': [('Microsoft', 'NNP'), ('home', 'NN'), ('state', 'NN'), ('Washington', 'NP'), ('also', 'RB'), ('enacted', 'VBN'), ('paid', 'VBN'), ('parental', 'JJ'), ('leave', 'VB'), ('go', 'VB'), ('effect', 'NN')]}
# {'subject': 'microsoft', 'action': 'said', 'object': 'blog', 'phrase': [('Microsoft', 'NNP'), ('general', 'JJ'), ('counsel', 'NN'), ('Dev', 'NN'), ('Stahlkopf', 'NN'), ('said', 'VBD'), ('blog', 'NN')]}
# {'subject': 'microsoft', 'action': 'required', 'object': 'suppliers', 'phrase': [('Microsoft', 'NNP'), ('required', 'VBN'), ('suppliers', 'NNS')]}

# %%
def merge_multi_word_subject(sentences, subject):
    """Merges multi word subjects into one single token
    ex. [('steve', 'NN', ('jobs', 'NN')] -> [('steve jobs', 'NN')]
    """
    if len(subject.split()) == 1:
        return sentences
    subject_lst = subject.split()
    sentences_lower = [[word.lower() for word in sentence]
                        for sentence in sentences]
    for i, sent in enumerate(sentences_lower):
        if subject_lst[0] in sent:
            for j, token in enumerate(sent):
                start = subject_lst[0] == token
                exists = subject_lst == sent[j:j+len(subject_lst)]
                if start and exists:
                    del sentences[i][j+1:j+len(subject_lst)]
                    sentences[i][j] = subject
    return sentences

# %%
def get_svo(sentence, subject):
    """Returns a dictionary containing:
    subject : the subject determined earlier
    action : the action verb of particular related to the subject
    object : the object the action is referring to
    phrase : list of token, tag pairs for that lie within the indexes of
                the variables above
    """
    subject_idx = next((i for i, v in enumerate(sentence)
                    if v[0].lower() == subject), None)
    data = {'subject': subject}
    for i in range(subject_idx, len(sentence)):
        found_action = False
        for j, (token, tag) in enumerate(sentence[i+1:]):
            if tag in VERBS:
                data['action'] = token
                found_action = True
            if tag in NOUNS and found_action == True:
                data['object'] = token
                data['phrase'] = sentence[i: i+j+2]
                return data
    return {}

# %%
top_10_entities = [word for word, count in nltk.FreqDist(entities).most_common(10)]

# %%
stopwords= set(stopwords.words('english'))

# %%
document = re.sub('[^A-Za-z .-]+', ' ', df.text[1])
document = ' '.join(document.split())
document = ' '.join([i for i in document.split() if i not in stopwords])

# %%
words = nltk.tokenize.word_tokenize(document)
words = [word.lower() for word in words if word not in stopwords]
fdist = nltk.FreqDist(words)
most_freq_nouns = [word for word, count in fdist.most_common(10)
                   if nltk.pos_tag([word])[0][1] in NOUNS]

# %%
most_freq_nouns
# Out:
# ['paid',
#  'offer',
#  'parental',
#  'microsoft',
#  'suppliers',
#  'washington',
#  'move',
#  'companies']

# %%
# def tokenize_sentences(document):
sentences = nltk.sent_tokenize(document)
sentences = [nltk.word_tokenize(sent) for sent in sentences]

# %%
sentences = [nltk.pos_tag(sent) for sent in sentences]

# %%
sentences[3]
# Out:
# [('Microsoft', 'NNP'),
#  ('move', 'NN'),
#  ('alone', 'RB'),
#  ('mean', 'VBD'),
#  ('many', 'JJ'),
#  ('thousands', 'NNS'),
#  ('new', 'JJ'),
#  ('workers', 'NNS'),
#  ('getting', 'VBG'),
#  ('paid', 'VBN'),
#  ('parental', 'JJ'),
#  ('leave', 'VBP'),
#  ('company', 'NN'),
#  ('partners', 'NNS'),
#  ('U.S', 'NNP'),
#  ('.', '.')]

# %%
# %xmode verbose
x = nltk.ne_chunk(sentences[6]) #entity recognition

# %%
x
# Out:
# Tree('S', [('As', 'IN'), ('looked', 'JJ'), ('legislation', 'NN'), ('however', 'RB'), ('realized', 'VBN'), ('benefit', 'NN'), ('employees', 'NNS'), ('suppliers', 'NNS'), Tree('GPE', [('Washington', 'NNP')]), ('state', 'NN'), ('leave', 'VBP'), ('thousands', 'NNS'), ('valued', 'VBN'), ('contributors', 'NNS'), ('outside', 'IN'), Tree('GPE', [('Washington', 'NNP')]), ('behind', 'IN'), Tree('ORGANIZATION', [('Microsoft', 'NNP')]), ('general', 'JJ'), ('counsel', 'NN'), Tree('PERSON', [('Dev', 'NNP'), ('Stahlkopf', 'NNP')]), ('said', 'VBD'), ('blog', 'NN'), ('post', 'NN'), ('.', '.')])

# %%
for chunk in x:
    print(chunk[0])
    print(type(chunk)) #entity recognition
# Out:
# As
# <class 'tuple'>
# looked
# <class 'tuple'>
# legislation
# <class 'tuple'>
# however
# <class 'tuple'>
# realized
# <class 'tuple'>
# benefit
# <class 'tuple'>
# employees
# <class 'tuple'>
# suppliers
# <class 'tuple'>
# ('Washington', 'NNP')
# <class 'nltk.tree.Tree'>
# state
# <class 'tuple'>
# leave
# <class 'tuple'>
# thousands
# <class 'tuple'>
# valued
# <class 'tuple'>
# contributors
# <class 'tuple'>
# outside
# <class 'tuple'>
# ('Washington', 'NNP')
# <class 'nltk.tree.Tree'>
# behind
# <class 'tuple'>
# ('Microsoft', 'NNP')
# <class 'nltk.tree.Tree'>
# general
# <class 'tuple'>
# counsel
# <class 'tuple'>
# ('Dev', 'NNP')
# <class 'nltk.tree.Tree'>
# said
# <class 'tuple'>
# blog
# <class 'tuple'>
# post
# <class 'tuple'>
# .
# <class 'tuple'>

# %%
entities = []
for tagged_sentence in sentences:
        for chunk in nltk.ne_chunk(tagged_sentence):
            if type(chunk) == nltk.tree.Tree:
                entities.append(' '.join([c[0] for c in chunk]).lower())

# %%
most_freq_nouns
# Out:
# ['paid',
#  'offer',
#  'parental',
#  'microsoft',
#  'suppliers',
#  'washington',
#  'move',
#  'companies']

# %%
entities
# Out:
# ['microsoft',
#  'history',
#  'microsoft',
#  'california',
#  'microsoft',
#  'washington',
#  'washington',
#  'washington',
#  'microsoft',
#  'dev stahlkopf',
#  'washingtons',
#  'national partnership',
#  'washington',
#  'history',
#  'microsoft']

# %%
top_10_entities = [w for w, c in nltk.FreqDist(entities).most_common(10)]

# %%
top_10_entities
# Out:
# ['microsoft',
#  'washington',
#  'history',
#  'california',
#  'dev stahlkopf',
#  'washingtons',
#  'national partnership']

# %%
#most used entities 
subject_nouns = [entity for entity in top_10_entities
                 if entity.split()[0] in most_freq_nouns]

# %%
subject_nouns
# Out:
# ['microsoft', 'washington']

# %%
# Try tagging the token with the bigram tagger.
# If the bigram tagger is unable to find a tag for the token, try the unigram tagger.
# If the unigram tagger is also unable to find a tag, use a default tagger.

# %%
from nltk import DefaultTagger, UnigramTagger, BigramTagger, TrigramTagger
nltk.download('conll2000')
nltk.download('treebank')
train_sents = nltk.corpus.brown.tagged_sents()
train_sents += nltk.corpus.conll2000.tagged_sents()
train_sents += nltk.corpus.treebank.tagged_sents()
# Create instance of SubjectTrigramTagger
t0 = DefaultTagger('NN')
t1 = UnigramTagger(train_sents, backoff=t0)
t2 = BigramTagger(train_sents, backoff=t1)
trigram_tagger = TrigramTagger(train_sents, backoff=t2)
# Out:
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/markrethana/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
trigram_tagger.tag(sent)

# %%
def get_svo(sentence, subject):
    """Returns a dictionary containing:
    subject : the subject determined earlier
    action : the action verb of particular related to the subject
    object : the object the action is referring to
    phrase : list of token, tag pairs for that lie within the indexes of
                the variables above
    """
    subject_idx = next((i for i, v in enumerate(sentence)
                    if v[0].lower() == subject), None)
    data = {'subject': subject}
    for i in range(subject_idx, len(sentence)):
        found_action = False
        for j, (token, tag) in enumerate(sentence[i+1:]):
            if tag in VERBS:
                data['action'] = token
                found_action = True
            if tag in NOUNS and found_action == True:
                data['object'] = token
                data['phrase'] = sentence[i: i+j+2]
                return data
    return {}

# %%
def get_entities(document):
    """Returns Named Entities using NLTK Chunking"""
    entities = []
    sentences = tokenize_sentences(document)

    # Part of Speech Tagging
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    for tagged_sentence in sentences:
        for chunk in nltk.ne_chunk(tagged_sentence):
            if type(chunk) == nltk.tree.Tree:
                entities.append(' '.join([c[0] for c in chunk]).lower())
    return entities

# %%
fdist.most_common(5)
# Out:
# [('.', 17), ('qualcomm', 14), ('apple', 9), ('use', 4), ('intel', 4)]

# %%
def box_plots(data, metric, title, sources_toshow_int):
    plot_data = []
    for source in (list(df.source_name.value_counts().index))[:sources_toshow_int]:
        plot_data.append(data[metric][(data.source_name == source)])
    fig, ax = plt.subplots()
    fig.set_size_inches(40, 20)
    ax.set_title("Distribution of Outlet's article "+title, fontsize=40)
    c = 'blue'
    ax.boxplot(plot_data)
    ax.set_xticklabels((list(df.source_name.value_counts().index))[:sources_toshow_int])
    plt.xticks(fontsize=20, rotation=90)
    plt.yticks(fontsize=20)
    plt.show()

# %%
box_plots(df,'pos','Positivity', 45)
box_plots(df,'neg','Negativity', 45)
box_plots(df,'compound','Compound', 45)
box_plots(df,'subjectivity','Subjectivity', 45)
